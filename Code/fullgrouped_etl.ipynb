# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
csv_file = os.path.join("..", "Resources", "COVID-19", "full_grouped.csv")
full_df = pd.read_csv(csv_file)
full_df.head()
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
clean_full_df = full_df[['Date', 'Country/Region', 'New cases','New deaths','New recovered']].copy()
clean_full_df.head()
# Out:
#          Date Country/Region  New cases  New deaths  New recovered
# 0  2020-01-22    Afghanistan          0           0              0
# 1  2020-01-22        Albania          0           0              0
# 2  2020-01-22        Algeria          0           0              0
# 3  2020-01-22        Andorra          0           0              0
# 4  2020-01-22         Angola          0           0              0

# %%
print(clean_full_df.dtypes)
# Out:
# Date              object
# Country/Region    object
# New cases          int64
# New deaths         int64
# New recovered      int64
# dtype: object

# %%
daywise_file = os.path.join("..", "Resources", "COVID-19","day_wise.csv")
daywise_df = pd.read_csv(daywise_file)
daywise_df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
clean_daywise_df = daywise_df[['Date', 'Confirmed','Active','New cases', 'No. of countries']].copy()
clean_daywise_df.head()
# Out:
#          Date  Confirmed  Active  New cases  No. of countries
# 0  2020-01-22        555     510          0                 6
# 1  2020-01-23        654     606         99                 8
# 2  2020-01-24        941     879        287                 9
# 3  2020-01-25       1434    1353        493                11
# 4  2020-01-26       2118    2010        684                13

# %%
print(clean_daywise_df.dtypes)
# Out:
# Date                object
# Confirmed            int64
# Active               int64
# New cases            int64
# No. of countries     int64
# dtype: object
